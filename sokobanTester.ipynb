# %%
import glob
import time
from sokoban import Warehouse

# %% [markdown]
# ## This Testing File
#
# There are two sections to this testing file:
# 1. Visualise results of functions on all the warehouses, including: the prediction, the time taken to produce the prediction.
# 2. Test your functions perform correctly on warehouse 1. This is similar to the tests that Gradescope will run.

# %%
#Import the mySokobanSolver.py file to import all functions
from mySokobanSolver import *

# %% [markdown]
# ## Visualise results

# %%
def test_warehouse(problem_file, macro = False):
    '''
    This function will test the performance of your warehouse for either macro or elem solutions and return the result.
    You can check if this solution works with your gui, or by cleverly using the check_action_seq function.
    '''

    wh = Warehouse()
    wh.load_warehouse(problem_file)

    if macro:
        student_answer =  solve_sokoban_macro(wh)
    else:
        student_answer = solve_sokoban_elem(wh)
        
    return student_answer
#.............................................................

# %%
'''

This script tests functions in your submission 'mySokobanSolver.py'

A similar script (with different inputs) will be used for marking your code.

Make sure that your code runs without errors with this script.


'''

def test_taboo_cells():
    wh = Warehouse()
    wh.load_warehouse("./warehouses/warehouse_0001.txt")
    expected_answer = '####  \n#X #  \n#  ###\n#   X#\n#   X#\n#XX###\n####  '
    answer = taboo_cells(wh)
    fcn = test_taboo_cells    
    print('<<  Testing {} >>'.format(fcn.__name__))
    if answer==expected_answer:
        print(fcn.__name__, ' passed!  :-)\n')
    else:
        print(fcn.__name__, ' failed!  :-(\n')
        print('Expected ');print(expected_answer)
        print('But, received ');print(answer)
        

def test_check_elem_action_seq():
    wh = Warehouse()
    wh.load_warehouse("./warehouses/warehouse_0001.txt")
    # first test
    answer = check_action_seq(wh, ['Right', 'Right','Down'])
    expected_answer = '####  \n# .#  \n#  ###\n#*   #\n#  $@#\n#  ###\n####  '
    fcn = test_check_elem_action_seq    
    print('<<  First test of {} >>'.format(fcn.__name__))
    if answer==expected_answer:
        print(fcn.__name__, ' passed!  :-)\n')
    else:
        print(fcn.__name__, ' failed!  :-(\n')
        print('Expected ');print(expected_answer)
        print('But, received ');print(answer)
    # second test
    answer = check_action_seq(wh, ['Right', 'Right','Right'])
    expected_answer = 'Failure'
    fcn = test_check_elem_action_seq    
    print('<<  Second test of {} >>'.format(fcn.__name__))
    if answer==expected_answer:
        print(fcn.__name__, ' passed!  :-)\n')
    else:
        print(fcn.__name__, ' failed!  :-(\n')
        print('Expected ');print(expected_answer)
        print('But, received ');print(answer)

def test_solve_sokoban_elem():
    puzzle_t1 ='#######\n#@ $. #\n#######'
    wh = Warehouse()    
    wh.extract_locations(puzzle_t1.split(sep='\n'))
    # first test
    answer = solve_sokoban_elem(wh)
    expected_answer = ['Right', 'Right']
    fcn = test_solve_sokoban_elem
    print('<<  First test of {} >>'.format(fcn.__name__))
    if answer==expected_answer:
        print(fcn.__name__, ' passed!  :-)\n')
    else:
        print(fcn.__name__, ' failed!  :-(\n')
        print('Expected ');print(expected_answer)
        print('But, received ');print(answer)
    # second test
    puzzle_t2 ='#######\n#@ $ #.#\n#######'
    wh = Warehouse()    
    wh.extract_locations(puzzle_t2.split(sep='\n'))
    # second test
    answer = solve_sokoban_elem(wh)
    expected_answer = 'Impossible'
    print('<<  Second test of {} >>'.format(fcn.__name__))
    if answer==expected_answer:
        print(fcn.__name__, ' passed!  :-)\n')
    else:
        print(fcn.__name__, ' failed!  :-(\n')
        print('Expected ');print(expected_answer)
        print('But, received ');print(answer)
        
def test_can_go_there():
    puzzle_t1 ='#######\n#@ $. #\n#######'
    wh = Warehouse()    
    wh.extract_locations(puzzle_t1.split(sep='\n'))
    # first test
    answer = can_go_there(wh,(1,2))
    expected_answer = True
    fcn = test_can_go_there
    print('<<  First test of {} >>'.format(fcn.__name__))
    if answer==expected_answer:
        print(fcn.__name__, ' passed!  :-)\n')
    else:
        print(fcn.__name__, ' failed!  :-(\n')
        print('Expected ');print(expected_answer)
        print('But, received ');print(answer)
    # second test
    answer = can_go_there(wh,(1,5))
    expected_answer = False
    print('<<  Second test of {} >>'.format(fcn.__name__))
    if answer==expected_answer:
        print(fcn.__name__, ' passed!  :-)\n')
    else:
        print(fcn.__name__, ' failed!  :-(\n')
        print('Expected ');print(expected_answer)
        print('But, received ');print(answer)

def test_solve_sokoban_macro():
    puzzle_t2 ='#######\n#@ $ .#\n#######'
    wh = Warehouse()    
    wh.extract_locations(puzzle_t2.split(sep='\n'))
    # first test
    answer=solve_sokoban_macro(wh)
    expected_answer = [((1, 3), 'Right'), ((1, 4), 'Right')]
    fcn = test_solve_sokoban_macro
    print('<<  First test of {} >>'.format(fcn.__name__))
    if answer==expected_answer:
        print(fcn.__name__, ' passed!  :-)\n')
    else:
        print(fcn.__name__, ' failed!  :-(\n')
        print('Expected ');print(expected_answer)
        print('But, received ');print(answer)

    
print('############################## Sanity Check Output ##############################')

print(my_team())  # should print your team
test_taboo_cells() 
test_check_elem_action_seq()
test_solve_sokoban_elem()
test_can_go_there()
test_solve_sokoban_macro()   

print('#################################################################################')
# Out:
# ############################## Sanity Check Output ##############################
# [(11710560, 'ASWIN', 'JAYARAMAN'), (10577505, 'Phi Long', 'Nguyen')]
# <<  Testing test_taboo_cells >>
# test_taboo_cells  passed!  :-)
#
# <<  First test of test_check_elem_action_seq >>
# test_check_elem_action_seq  passed!  :-)
#
# <<  Second test of test_check_elem_action_seq >>
# test_check_elem_action_seq  passed!  :-)
#
# <<  First test of test_solve_sokoban_elem >>
# test_solve_sokoban_elem  passed!  :-)
#
# <<  Second test of test_solve_sokoban_elem >>
# test_solve_sokoban_elem  passed!  :-)
#
# <<  First test of test_can_go_there >>
# test_can_go_there  passed!  :-)
#
# <<  Second test of test_can_go_there >>
# test_can_go_there  passed!  :-)
#
# <<  First test of test_solve_sokoban_macro >>
# test_solve_sokoban_macro  passed!  :-)
#
# #################################################################################

# %%
all_warehouses = sorted(glob.glob('warehouses/*.txt'))
print(len(all_warehouses))
# Out:
# 103

# %%
# all_warehouses = sorted(glob.glob('warehouses/*.txt'))
# # all_warehouses = ('warehouses/warehouse_0001.txt')

for problem_file in all_warehouses:
    print(f'Testing {problem_file}')
    s = time.time()
    a = test_warehouse(problem_file)
    print(f'Answer: {a}')
    print(f'Time taken: {time.time()-s :.3f} seconds')
# Out:
# Testing warehouses/warehouse_0001.txt
# Answer: ['Down', 'Left', 'Up', 'Right', 'Right', 'Right', 'Down', 'Left', 'Up', 'Left', 'Left', 'Down', 'Down', 'Right', 'Up', 'Left', 'Up', 'Right', 'Up', 'Up', 'Left', 'Down', 'Right', 'Down', 'Down', 'Right', 'Right', 'Up', 'Left', 'Down', 'Left', 'Up', 'Up']
# Time taken: 0.031 seconds
# Testing warehouses/warehouse_0003.txt
# Answer: ['Right', 'Up', 'Up', 'Left', 'Left', 'Left', 'Up', 'Left', 'Down', 'Right', 'Right', 'Right', 'Right', 'Down', 'Down', 'Left', 'Up', 'Right', 'Up', 'Left', 'Left', 'Left', 'Down', 'Down', 'Left', 'Left', 'Left', 'Up', 'Up', 'Right', 'Right', 'Down', 'Right', 'Down', 'Left', 'Up', 'Up', 'Up', 'Right', 'Down', 'Down']
# Time taken: 0.392 seconds
# Testing warehouses/warehouse_0005.txt
# Answer: ['Left', 'Up', 'Right', 'Left', 'Left', 'Down', 'Right', 'Down', 'Right', 'Down', 'Right', 'Right', 'Up', 'Up', 'Left', 'Left', 'Down', 'Left', 'Up', 'Down', 'Down', 'Left', 'Left', 'Up', 'Right']
# Time taken: 22.141 seconds
# Testing warehouses/warehouse_0007.txt
# Answer: ['Left', 'Left', 'Up', 'Right', 'Up', 'Up', 'Left', 'Up', 'Up', 'Right', 'Right', 'Down', 'Right', 'Right', 'Down', 'Down', 'Left', 'Left', 'Right', 'Up', 'Right', 'Down', 'Down', 'Down', 'Left', 'Up']
# Time taken: 68.812 seconds
# Testing warehouses/warehouse_0009.txt
# Answer: ['Up', 'Right', 'Right', 'Down', 'Up', 'Left', 'Left', 'Down', 'Right', 'Down', 'Right', 'Left', 'Up', 'Up', 'Right', 'Down', 'Right', 'Down', 'Down', 'Left', 'Up', 'Right', 'Up', 'Left', 'Down', 'Left', 'Up', 'Right', 'Up', 'Left']
# Time taken: 0.029 seconds
# Testing warehouses/warehouse_0011.txt
# Answer: ['Up', 'Left', 'Left', 'Left', 'Down', 'Down', 'Down', 'Down', 'Right', 'Right', 'Right', 'Right', 'Up', 'Left', 'Down', 'Left', 'Left', 'Left', 'Up', 'Up', 'Up', 'Up', 'Right', 'Right', 'Right', 'Down', 'Down', 'Down', 'Right', 'Down', 'Left', 'Left', 'Left', 'Left', 'Up', 'Left', 'Left', 'Down', 'Down', 'Right', 'Up', 'Left', 'Up', 'Right', 'Down', 'Right', 'Right', 'Right', 'Right', 'Up', 'Up', 'Left', 'Down', 'Right', 'Down', 'Left', 'Left', 'Left', 'Up', 'Left', 'Left', 'Down', 'Down', 'Right', 'Up', 'Right', 'Right', 'Right', 'Right', 'Up', 'Up', 'Up', 'Up', 'Left', 'Left', 'Left', 'Down', 'Down']
# Time taken: 0.778 seconds
# Testing warehouses/warehouse_0013.txt
# Answer: ['Right', 'Down', 'Left', 'Down', 'Down', 'Right', 'Down', 'Down', 'Left', 'Up', 'Up', 'Up', 'Up', 'Right', 'Up', 'Left', 'Down', 'Down', 'Down', 'Right', 'Down', 'Right', 'Right', 'Up', 'Left', 'Left', 'Down', 'Left', 'Up', 'Up', 'Up', 'Left', 'Up', 'Down', 'Right', 'Right', 'Down', 'Down', 'Right', 'Down', 'Left', 'Down', 'Left', 'Up', 'Up', 'Up', 'Right', 'Up', 'Left', 'Right', 'Up', 'Left']
# Time taken: 5.187 seconds
# Testing warehouses/warehouse_0015.txt
# Answer: ['Down', 'Right', 'Down', 'Down', 'Down', 'Left', 'Left', 'Up', 'Up', 'Down', 'Down', 'Right', 'Right', 'Up', 'Up', 'Left', 'Up', 'Left', 'Left', 'Left', 'Down', 'Left', 'Left', 'Up', 'Right', 'Right', 'Right', 'Right', 'Down', 'Right', 'Right', 'Down', 'Down', 'Left', 'Left', 'Up', 'Up']
# Time taken: 0.095 seconds
# Testing warehouses/warehouse_0017.txt
# Answer: ['Right', 'Down', 'Down', 'Up', 'Left', 'Left', 'Down', 'Right', 'Down', 'Down', 'Right', 'Right', 'Up', 'Left', 'Up', 'Down', 'Down', 'Left', 'Up', 'Up', 'Down', 'Down', 'Left', 'Up', 'Up']
# Time taken: 0.176 seconds
# Testing warehouses/warehouse_0019.txt
# Answer: ['Up', 'Right', 'Right', 'Down', 'Down', 'Down', 'Left', 'Down', 'Down', 'Right', 'Up', 'Up', 'Up', 'Up', 'Right', 'Up', 'Left', 'Left', 'Left', 'Down', 'Right', 'Up', 'Right', 'Down', 'Down', 'Down', 'Left', 'Down', 'Down', 'Right', 'Up', 'Up', 'Up', 'Up', 'Left', 'Left', 'Left', 'Left', 'Up', 'Right', 'Right']
# Time taken: 0.199 seconds
# Testing warehouses/warehouse_0021.txt
# Answer: ['Down', 'Left', 'Left', 'Up', 'Down', 'Left', 'Up', 'Left', 'Up', 'Up', 'Right', 'Down', 'Right', 'Down', 'Down', 'Left', 'Up']
# Time taken: 0.018 seconds
# Testing warehouses/warehouse_0023.txt
# Answer: ['Right', 'Up', 'Up', 'Left', 'Left', 'Up', 'Right', 'Down', 'Right', 'Down', 'Down', 'Left', 'Down', 'Left', 'Up', 'Up', 'Down', 'Right', 'Right', 'Up', 'Up', 'Left', 'Up', 'Left', 'Left', 'Down', 'Right', 'Down', 'Down', 'Right', 'Right', 'Up', 'Up', 'Right', 'Up', 'Left', 'Left', 'Right', 'Down', 'Down', 'Down', 'Left', 'Left', 'Up', 'Up', 'Right', 'Up', 'Right', 'Down', 'Down', 'Up', 'Left', 'Left', 'Left', 'Up', 'Right']
# Time taken: 0.104 seconds
# Testing warehouses/warehouse_0025.txt
# Answer: ['Up', 'Right', 'Right', 'Down', 'Left', 'Up', 'Left', 'Left', 'Up', 'Up', 'Right', 'Down', 'Left', 'Down', 'Right', 'Left', 'Down', 'Down', 'Right', 'Up', 'Right', 'Right', 'Up', 'Up', 'Left', 'Left', 'Up', 'Left', 'Down']
# Time taken: 0.182 seconds
# Testing warehouses/warehouse_0027.txt
# Answer: ['Down', 'Left', 'Up', 'Left', 'Down', 'Down', 'Left', 'Left', 'Up', 'Up', 'Up', 'Up', 'Right', 'Right', 'Right', 'Down', 'Up', 'Left', 'Left', 'Left', 'Down', 'Down', 'Down', 'Down', 'Right', 'Right', 'Up', 'Up', 'Left', 'Right', 'Down', 'Right', 'Right', 'Up', 'Left', 'Up', 'Up', 'Left', 'Left', 'Left', 'Down', 'Down', 'Down', 'Up', 'Right', 'Right', 'Down', 'Right', 'Up', 'Up']
# Time taken: 0.133 seconds
# Testing warehouses/warehouse_0029.txt
# Answer: ['Left', 'Up', 'Left', 'Left', 'Down', 'Right', 'Up', 'Right', 'Right', 'Down', 'Right', 'Right', 'Down', 'Down', 'Left', 'Left', 'Left', 'Left', 'Left', 'Left', 'Left', 'Up', 'Up', 'Right', 'Up', 'Right', 'Right', 'Down', 'Right', 'Right', 'Right', 'Left', 'Left', 'Left', 'Up', 'Left', 'Left', 'Down', 'Right', 'Right', 'Left', 'Left', 'Left', 'Down', 'Down', 'Right', 'Right', 'Right', 'Right', 'Right', 'Right', 'Right', 'Up', 'Up', 'Up', 'Up', 'Down', 'Down', 'Left', 'Left', 'Up', 'Left', 'Left', 'Down', 'Right', 'Right', 'Right', 'Left', 'Left', 'Left', 'Left', 'Left', 'Left', 'Down', 'Down', 'Right', 'Right', 'Right', 'Right', 'Right', 'Right', 'Right', 'Up', 'Up', 'Up', 'Right', 'Up', 'Up', 'Left', 'Down', 'Down', 'Down', 'Up', 'Up', 'Up', 'Up', 'Left', 'Left', 'Down', 'Right', 'Up', 'Right', 'Down', 'Down']
# Time taken: 10.017 seconds
# Testing warehouses/warehouse_0031.txt
# Answer: ['Right', 'Left', 'Down', 'Left', 'Down', 'Right', 'Right', 'Down', 'Right', 'Right', 'Up', 'Up', 'Left', 'Left', 'Up', 'Left', 'Down']
# Time taken: 0.142 seconds
# Testing warehouses/warehouse_0033.txt
# Answer: ['Up', 'Left', 'Left', 'Right', 'Right', 'Down', 'Down', 'Left', 'Left', 'Left', 'Up', 'Left', 'Up', 'Up', 'Right', 'Down', 'Left', 'Down', 'Down', 'Right', 'Right', 'Up', 'Down', 'Right', 'Right', 'Up', 'Up', 'Left', 'Left', 'Left', 'Right', 'Down', 'Down', 'Left', 'Left', 'Up', 'Up', 'Right', 'Right', 'Down', 'Left']
# Time taken: 3.718 seconds
# Testing warehouses/warehouse_0035.txt
